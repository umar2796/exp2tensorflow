# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense

# %%
cifar=tf.keras.datasets.cifar10
(x_train,y_train),(x_test,y_test)=cifar.load_data()

# %%
x_train[1].shape
# Out:
# (32, 32, 3)

# %%
plt.matshow(x_train[1])

# %%
model_10 = tf.keras.Sequential([
  Conv2D(filters=32,kernel_size=(3, 3), activation='relu', input_shape=(32,32, 3)),
  MaxPool2D(),
  Conv2D(filters=32,kernel_size=(3, 3), activation='relu'),
  MaxPool2D(),
  Flatten(),
  Dense(100, activation='relu'),
  Dense(10, activation='softmax')
])

model_10.compile(loss='sparse_categorical_crossentropy',
                 optimizer='adam',
                 metrics=['accuracy'])


history_10 = model_10.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=5 )
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 63s 39ms/step - loss: 2.1684 - accuracy: 0.2288 - val_loss: 1.6891 - val_accuracy: 0.3718
# Epoch 2/5
# 1563/1563 [==============================] - 59s 38ms/step - loss: 1.5400 - accuracy: 0.4466 - val_loss: 1.3812 - val_accuracy: 0.5098
# Epoch 3/5
# 1563/1563 [==============================] - 79s 50ms/step - loss: 1.2663 - accuracy: 0.5522 - val_loss: 1.2626 - val_accuracy: 0.5717
# Epoch 4/5
# 1563/1563 [==============================] - 90s 58ms/step - loss: 1.1188 - accuracy: 0.6096 - val_loss: 1.1449 - val_accuracy: 0.6122
# Epoch 5/5
# 1563/1563 [==============================] - 109s 69ms/step - loss: 1.0299 - accuracy: 0.6450 - val_loss: 1.0749 - val_accuracy: 0.6310

# %%
pd.DataFrame(history_10.history).plot()
# Out:
# <AxesSubplot:>
